# %% [markdown]
# # 03 — Generate figures
#
# Select a dataset and metric, then plot generator comparison or seed stability.

# %%
import sys
from pathlib import Path
BATCH = Path.cwd()
if BATCH.name != "1st batch":
    BATCH = Path("..").resolve()
sys.path.insert(0, str(BATCH))
from src.figures import plot_generator_comparison, plot_seed_stability

dataset = "Cancer"
metric = "Quality_Score"
print(plot_generator_comparison(dataset, metric, metric_category="Fidelity"))
print(plot_seed_stability(dataset, metric))
