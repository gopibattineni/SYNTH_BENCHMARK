# %% [markdown]
# # 01 — Run multi-seed experiment (Batch 1)
#
# Calls the reusable pipeline in `src/`. Does not modify the original SYNTH notebooks.

# %%
import sys
from pathlib import Path
BATCH = Path.cwd()
if BATCH.name != "1st batch":
    BATCH = Path("..").resolve()
sys.path.insert(0, str(BATCH))
from src.config_loader import load_datasets, generator_names, load_seeds
from src.experiment import run_experiment, run_one
print("datasets", len(load_datasets()))
print("generators", generator_names())
print("seeds", load_seeds()["generator_seeds"])

# %%
# Smoke: Cancer × CTGAN × one seed
print(run_one("cancer", "CTGAN", 42))

# %%
# Uncomment to launch the full resumable 360-run experiment:
# run_experiment()  # all datasets × generators × seeds
