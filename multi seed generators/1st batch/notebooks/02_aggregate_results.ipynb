# %% [markdown]
# # 02 — Aggregate multi-seed results (mean ± SD, ddof=1)

# %%
import sys
from pathlib import Path
BATCH = Path.cwd()
if BATCH.name != "1st batch":
    BATCH = Path("..").resolve()
sys.path.insert(0, str(BATCH))
from src.aggregate import aggregate, load_raw
raw = load_raw()
print("raw rows", len(raw))
agg = aggregate(raw)
display(agg.head(20))
